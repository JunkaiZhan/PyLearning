# %%
# 使用requests可以更方便的处理Cookies，代理设置和登录验证等操作
# 之前使用urllib可是实现，但是操作起来相对会比较麻烦，需要先构造数据结构，实例化句柄，在创建opener

import requests

# 在urllib中，要制定请求类型需要实例化Reuqest对象，并在其参数中指定
# 而在requests库中，可以直接使用不同的请求函数
resp = requests.get("http://www.baidu.com")
print("Type of resp >>> ", type(resp))
print("Type of resp.text >>> ", type(resp.text))
print("Type of resp.cookies >>> ", type(resp.cookies))
print("resp.status_code >>>", resp.status_code)
print("resp.text >>> \n", resp.text)
print("resp.cookies >>> \n", resp.cookies)

resp = requests.post("http://httpbin.org/post")
resp = requests.put("http://httpbin.org/put")
resp = requests.delete("http://httpbin.org/delete")
resp = requests.head("http://httpbin.org/head")
resp = requests.options("http://httpbin.org/options")

# %%
import requests
import re

# Just get
r = requests.get('http://httpbin.org/get')
print(r.text)

# Add parameters
data = {"name": "HelloWorld", "age": "18"}
r = requests.get('http://httpbin.org/get', params = data)
print(r.text)

# Covert the response text from json to dict
print("Type of r.text >>> ", type(r.text))
print("Type of r.json >>> ", type(r.json()))
print("r.json >>> \n", r.json())

# %%
import requests
import re

# Add header to get a page
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'
}
r = requests.get("https://www.zhihu.com/explore", headers = headers)
print(r.text)
pattern = re.compile('explore-feed.*?question_link.*?>(.*?)</a>', re.S)
titles  = re.findall(pattern, r.text)

for _ in titles: print(_)
# Out:
# nswerCount":1271},{"followerCount":33865,"title":"家长要在孩子面前表露出「赚钱辛苦、我们家不富裕」这样的态度吗？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F296333267","type":"question","id":296333267,"answerCount":4209}],"logo":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-1c4bdfa66a0ea622c7f5c7f69d9fd245_hd.jpg","urlToken":"buwanmeifumu"},"zhengquerenshiyouxiz":{"startAt":1576112400,"name":"正确认识游戏障碍","title":"正确认识游戏障碍","color":"#61afe2","banner":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-5fe8f52572dac9d23dcf32c4c10d3804_hd.jpg","tinyBanner":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-beb7b6ef5218754c1d9e2bb0be40705d_hd.jpg","endAt":1576760400,"url":"\u002Froundtables\u002Fexplore\u002Fcards\u002Froundtable\u002Fzhengquerenshiyouxiz","followersCount":320,"intro":"如今游戏和电子竞技风靡全球，发展态势良好，游戏上瘾也得到了越来越多的关注，家长 、学校多视其为洪水猛兽。2019 年 WHO 将游戏上瘾称为游戏障碍，也进一步引发了社会、大众和科研人员对其的关注。那么，如何正确看待、应对和处理游戏障碍，将成为重要问题。","isFollowing":false,"guests":[{"avatarUrl":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-bd2a26a466a816d1704861d56951136b_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002F50\u002Fv2-8cace9f192dcfa23d67bc77012dd3eaa_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fv2-1511a54a5070cef56cb0b2903311f40b_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-9536a71850fcb34215f276cf8b936124_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002F50\u002Fv2-a6eec574880b6996f575c28125c3c32d_hd.jpg"}],"questions":[{"followerCount":540,"title":"如果孩子很喜欢玩《王者荣耀》，作为家长应该如何处理游戏和学习、生活的关系，维护亲子关系和学习成绩？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F61988897","type":"question","id":61988897,"answerCount":82},{"followerCount":5,"title":"谈「游戏成瘾」和「网瘾治疗」色变的今天，媒体们起到了什么作用？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F360056924","type":"question","id":360056924,"answerCount":0},{"followerCount":440,"title":"初中生希望成为电竞选手，让他在暑假尝试一下可以吗？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F359623996","type":"question","id":359623996,"answerCount":257}],"logo":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fv2-f6994d8229dd3e293b3532479f80d52b_hd.jpg","urlToken":"zhengquerenshiyouxiz"}},"order":["2019","huhangjihua","buwanmeifumu","zhengquerenshiyouxiz"]},"collections":{"36789880":{"favitems":[{"content":{"updated":1566045884,"author":{"avatarUrlTemplate":"https:\u002F\u002Fpic1.zhimg.com\u002Fv2-bcc80a1da2860abe8dbfa4dc07907c34_{size}.jpg","type":"people","name":"只有我","headline":"学生","urlToken":"zhi-you-wo-43-17","userType":"people","isAdvertiser":false,"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002Fv2-bcc80a1da2860abe8dbfa4dc07907c34_is.jpg","isOrg":false,"gender":1,"url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fpeople\u002Fda95a280978150f5ab8da667ad375290","badge":[],"id":"da95a280978150f5ab8da667ad375290"},"url":"http:\u002F\u002Fzhuanlan.zhihu.com\u002Fp\u002F78609747","commentPermission":"all","title":"Python 深度集成的神器级 IDE，从此告别Excel！","excerpt":"这是一款与 Python 深度集成、基于 Web 开发、无需在各个工具之间切换、适用大部分职业工作场景的开源电子表格应用程序。对它的评价只有 Wow awesome，amazing！一位名叫 Rick Lamers 的外国小哥开源了一款与 \u003Ca href=\"https:\u002F\u002Flink.zhihu.com\u002F?target=https%3A\u002F\u002Fs.geekbang.org\u002Fsearch\u002Fc%3D2\u002Fk%3DPython\u002Ft%3D\" class=\" wrap external\" target=\"_blank\" rel=\"nofollow noreferrer\"\u003EPython \u003C\u002Fa\u003E深度集成、基于 \u003Ca href=\"https:\u002F\u002Flink.zhihu.com\u002F?target=https%3A\u002F\u002Fs.geekbang.org\u002Fsearch\u002Fc%3D2\u002Fk%3Dweb\u002Ft%3D\" class=\" wrap external\" target=\"_blank\" rel=\"nofollow noreferrer\"\u003EWeb \u003C\u002Fa\u003E的电子表格应用程序…","created":1566045884,"commentCount":17,"imageUrl":"","excerptTitle":"","type":"article","id":78609747,"voteupCount":294}},{"content":{"isCollapsed":false,"author":{"avatarUrlTemplate":"https:\u002F\u002Fpic3.zhimg.com\u002Fv2-fa868ddbb66efb98bf9548869c730bdf_{size}.jpg","type":"people","name":"鹏哥说房产","headline":"公众号【鹏哥说房】，年轻人房产加油第一站，带你轻松避坑","urlToken":"da-peng-zhan-chi-19","userType":"people","isAdvertis ...

# %%
import requests

# Save the content into file in specified type
r = requests.get("https://github.com/favicon.ico")
print("r.text >>> ", r.text)
print("r.content >>> ", r.content)
with open('favicon.ico', 'wb') as f:
    f.write(r.content)
# Out:
# 0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x15\x15+\x0c\x1e\x1e\x1e\x11\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1b\x1b\x1b\x1c$$$#\x17\x17\x18\x92\x15\x15\x17\xf1\x16\x16\x17\xf3@@@\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x16\x16\x18\xed\x16\x16\x17\xf3\x16\x16\x18\x95\x1c\x1c\x1c%\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00$$$\x07\x16\x16\x18\x80\x16\x16\x18\xf8\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff   \x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x15\x15\x17\xfe\x15\x15\x17\xff\x15\x15\x17\xff\x16\x16\x18\xf9\x16\x16\x18\x82   +++/\x15\x15\x17\xe6\x15\x15\x17\xff\x15\x15\x17\xfc\x16\x16\x18\xb8\x16\x16\x18t\x16\x16\x19g\x16\x16\x18~UUU\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x15\x15\x17\xfc\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xe6\x16\x16\x1b/\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1a\x1a\x1a\x1d\x15\x15\x17\xe6\x15\x15\x17\xff\x15\x15\x17\xfc\x18\x18\x18I$$$\x07\x16\x16\x17\xd1\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x18\x9d\x00\x00\x00\x00\x15\x15 \x18\x16\x16\x18s\x15\x15\x17\x90\x17\x17\x19f$$$$$$\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x16\x16\x18\x81\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xf1\x1b\x1b\x1b\x1c\x1c\x1c\x1c%\x16\x16\x18\xeb\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x17\x17\x1aN\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x18\x18\x18@\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x15\x15\x17\xff\x16\x16\x18\x80\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x15\x15\x1c$\x16\x16\x18\xf9\x15\x15\x17\xff\x15\x15\x18\xee\x16\x16\x1aE\x15\x15+\x0c\x16\x16\x17\xc ...
